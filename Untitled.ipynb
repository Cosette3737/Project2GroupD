# %%
#Add dependencies
import pandas as pd
from sqlalchemy import create_engine
import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import numpy as np
import calendar

# %%
#create engine to connect to SQL database
engine = create_engine("postgresql://postgres:postgres@localhost/project2")
#connect to SQL database
connection = engine.connect()

# %%
 pd.read_sql("select * from driverwins", connection)
# Out:
#      driverid  wins   forename     surname nationality
# 0           1    95      Lewis    Hamilton     British
# 1          30    91    Michael  Schumacher      German
# 2          20    53  Sebastian      Vettel      German
# 3         117    51      Alain       Prost      French
# 4         102    41     Ayrton       Senna   Brazilian
# ..        ...   ...        ...         ...         ...
# 105         5     1     Heikki  Kovalainen     Finnish
# 106       766     1        Lee     Wallard    American
# 107       786     1      Luigi     Fagioli     Italian
# 108       813     1     Pastor   Maldonado  Venezuelan
# 109       815     1     Sergio       Pérez     Mexican
#
# [110 rows x 5 columns]

# %%
 pd.read_sql("SELECT * FROM driverWins limit 5", connection)
# Out:
#    driverid  wins   forename     surname nationality
# 0         1    95      Lewis    Hamilton     British
# 1        30    91    Michael  Schumacher      German
# 2        20    53  Sebastian      Vettel      German
# 3       117    51      Alain       Prost      French
# 4       102    41     Ayrton       Senna   Brazilian

# %%
pd.read_sql("SELECT nationality, SUM(wins) AS 'wins' FROM driver Wins GROUP BY nationality ORDER BY wins DESC;", connection)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# SyntaxError: syntax error at or near "'wins'"
# LINE 1: SELECT nationality, SUM(wins) AS 'wins' FROM driver Wins GRO...
#                                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...
